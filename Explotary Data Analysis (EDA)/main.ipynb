# %% [markdown]
# # Explotary Data Analysis (EDA)

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns


import kagglehub
plt.style.use("ggplot")

# %%
df = pd.read_csv("coaster_db.csv")

# %%
df.shape
# Out:
# (1087, 56)

# %%
df.head(10)
# Out:
#                              coaster_name            Length             Speed  \
# 0                      Switchback Railway    600 ft (180 m)  6 mph (9.7 km/h)
# 1                       Flip Flap Railway               NaN               NaN
# 2  Switchback Railway (Euclid Beach Park)               NaN               NaN
# 3            Loop the Loop (Coney Island)               NaN               NaN
# 4            Loop the Loop (Young's Pier)               NaN               NaN
# 5                          Cannon Coaster               NaN               NaN
# 6                           Leap-The-Dips  1,452 ft (443 m)  10 mph (16 km/h)
# 7        Figure Eight (Euclid Beach Park)               NaN               NaN
# 8                            Drop the Dip               NaN               NaN
# 9      Scenic Railway (Euclid Beach Park)               NaN               NaN
#
#                          Location     Status   Opening date  \
# ...

# %%
df.tail()
# Out:
#                         coaster_name                Length  \
# 1082         American Dreier Looping    3,444 ft (1,050 m)
# 1083       Pantheon (roller coaster)    3,328 ft (1,014 m)
# 1084       Tron Lightcycle Power Run  3,169.3 ft (966.0 m)
# 1085                         Tumbili        770 ft (230 m)
# 1086  Wonder Woman Flight of Courage    3,300 ft (1,000 m)
#
#                         Speed                    Location              Status  \
# 1082         53 mph (85 km/h)                       Other                 NaN
# 1083        73 mph (117 km/h)  Busch Gardens Williamsburg  Under construction
# 1084  59.3[1] mph (95.4 km/h)                       Other                 NaN
# 1085         34 mph (55 km/h)              Kings Dominion  Under construction
# 1086         58 mph (93 km/h)    Six Flags Magic Mountain  Under construction
#
#        Opening date                                  Type  \
# 1082            NaN                                 Steel
# ...

# %%
df.columns
# Out:
# Index(['coaster_name', 'Length', 'Speed', 'Location', 'Status', 'Opening date',
#        'Type', 'Manufacturer', 'Height restriction', 'Model', 'Height',
#        'Inversions', 'Lift/launch system', 'Cost', 'Trains', 'Park section',
#        'Duration', 'Capacity', 'G-force', 'Designer', 'Max vertical angle',
#        'Drop', 'Soft opening date', 'Fast Lane available', 'Replaced',
#        'Track layout', 'Fastrack available', 'Soft opening date.1',
#        'Closing date', 'Opened', 'Replaced by', 'Website',
#        'Flash Pass Available', 'Must transfer from wheelchair', 'Theme',
#        'Single rider line available', 'Restraint Style',
#        'Flash Pass available', 'Acceleration', 'Restraints', 'Name',
#        'year_introduced', 'latitude', 'longitude', 'Type_Main',
#        'opening_date_clean', 'speed1', 'speed2', 'speed1_value', 'speed1_unit',
#        'speed_mph', 'height_value', 'height_unit', 'height_ft',
#        'Inversions_clean', 'Gforce_clean'],
# ...

# %%
df.dtypes
# Out:
# coaster_name                      object
# Length                            object
# Speed                             object
# Location                          object
# Status                            object
# Opening date                      object
# Type                              object
# Manufacturer                      object
# Height restriction                object
# Model                             object
# Height                            object
# Inversions                       float64
# Lift/launch system                object
# Cost                              object
# Trains                            object
# Park section                      object
# Duration                          object
# Capacity                          object
# G-force                           object
# Designer                          object
# Max vertical angle                object
# Drop                              object
# Soft opening date                 object
# ...

# %%
df.describe()
# Out:
#        Inversions  year_introduced    latitude   longitude  speed1_value  \
# count  932.000000      1087.000000  812.000000  812.000000    937.000000
# mean     1.547210      1994.986201   38.373484  -41.595373     53.850374
# std      2.114073        23.475248   15.516596   72.285227     23.385518
# min      0.000000      1884.000000  -48.261700 -123.035700      5.000000
# 25%      0.000000      1989.000000   35.031050  -84.552200     40.000000
# 50%      0.000000      2000.000000   40.289800  -76.653600     50.000000
# 75%      3.000000      2010.000000   44.799600    2.778100     63.000000
# max     14.000000      2022.000000   63.230900  153.426500    240.000000
#
#         speed_mph  height_value   height_ft  Inversions_clean  Gforce_clean
# count  937.000000    965.000000  171.000000       1087.000000    362.000000
# mean    48.617289     89.575171  101.996491          1.326587      3.824006
# std     16.678031    136.246444   67.329092          2.030854      0.989998
# ...

# %%
# df.drop(columns=['column_name_1', 'column_name_2'], inplace=True)

df_new =df[['coaster_name', 
#'Length', 'Speed', 'Status', 'Opening date', 'Type', 
'Manufacturer', 'Location',
#'Height restriction', 'Model', 'Height','Inversions', 'Lift/launch system', 'Cost', 'Trains', 'Park section','Duration', 'Capacity', 'G-force', 'Designer', 'Max vertical angle', 'Drop', 'Soft opening date', 'Fast Lane available', 'Replaced',
# 'Track layout', 'Fastrack available', 'Soft opening date.1','Closing date', 
'Opened', 
#'Replaced by', 'Website','Flash Pass Available', 'Must transfer from wheelchair', 'Theme','Single rider line available', 'Restraint Style','Flash Pass available', 'Acceleration', 'Restraints', 'Name',
       'year_introduced', 'latitude', 'longitude', 'Type_Main',
       'opening_date_clean', 
#'speed1', 'speed2', 'speed1_value', 'speed1_unit',
       'speed_mph', 
#'height_value', 'height_unit', 
'height_ft','Inversions_clean', 'Gforce_clean']].copy()

# %%
df_new.shape
# Out:
# (1087, 13)

# %%
df_new.dtypes
# Out:
# coaster_name           object
# Manufacturer           object
# Location               object
# Opened                 object
# year_introduced         int64
# latitude              float64
# longitude             float64
# Type_Main              object
# opening_date_clean     object
# speed_mph             float64
# height_ft             float64
# Inversions_clean        int64
# Gforce_clean          float64
# dtype: object

# %%
df_new['opening_date_clean'] = pd.to_datetime(df_new['opening_date_clean'])

# %%
df_new["year_introduced"]=pd.to_numeric(df_new["year_introduced"])

# %% [markdown]
# # Rename columns

# %%
df_new=df_new.rename(columns={"coaster_name":"Coaster_Name","year_introduced":"Year_Introduced","opening_date_clean":"Opening_Date","speed_mph":"Speed (mph)","height_ft":"Height (ft)","Inversions_clean":"Inversions","Gforce_clean":"Gforce"})

# %%
df_new.head()
# Out:
#                              Coaster_Name            Manufacturer  \
# 0                      Switchback Railway  LaMarcus Adna Thompson
# 1                       Flip Flap Railway            Lina Beecher
# 2  Switchback Railway (Euclid Beach Park)                     NaN
# 3            Loop the Loop (Coney Island)          Edwin Prescott
# 4            Loop the Loop (Young's Pier)          Edwin Prescott
#
#                          Location Opened  Year_Introduced  latitude  \
# 0                    Coney Island    NaN             1884   40.5740
# 1                   Sea Lion Park    NaN             1895   40.5780
# 2  Cleveland, Ohio, United States   1895             1896   41.5800
# 3                           Other    NaN             1901   40.5745
# 4                           Other    NaN             1901   39.3538
#
#    longitude Type_Main Opening_Date  Speed (mph)  Height (ft)  Inversions  \
# 0   -73.9780      Wood   1884-06-16          6.0          NaN           0
# ...

# %%
df_new.isna().sum()
# Out:
# Coaster_Name          0
# Manufacturer         59
# Location              0
# Opened             1060
# Year_Introduced       0
# latitude            275
# longitude           275
# Type_Main             0
# Opening_Date        250
# Speed (mph)         150
# Height (ft)         916
# Inversions            0
# Gforce              725
# dtype: int64

# %%
df_new = df_new.loc[~df_new.duplicated(subset=["Coaster_Name", "Location", "Opening_Date"])].reset_index(drop=True).copy()

# %%
df_new.query("Coaster_Name =='Crystal Beach Cyclone'")
# Out:
#              Coaster_Name        Manufacturer            Location Opened  \
# 39  Crystal Beach Cyclone  Traver Engineering  Crystal Beach Park    NaN
#
#     Year_Introduced  latitude  longitude Type_Main Opening_Date  Speed (mph)  \
# 39             1926   42.8617   -79.0598      Wood   1926-01-01         60.0
#
#     Height (ft)  Inversions  Gforce
# 39          NaN           0     4.0

# %%
df_new
# Out:
#                                Coaster_Name                 Manufacturer  \
# 0                        Switchback Railway       LaMarcus Adna Thompson
# 1                         Flip Flap Railway                 Lina Beecher
# 2    Switchback Railway (Euclid Beach Park)                          NaN
# 3              Loop the Loop (Coney Island)               Edwin Prescott
# 4              Loop the Loop (Young's Pier)               Edwin Prescott
# ..                                      ...                          ...
# 985            Ice Breaker (roller coaster)                Premier Rides
# 986                   Leviathan (Sea World)           Martin & Vleminckx
# 987               Pantheon (roller coaster)                      Intamin
# 988                                 Tumbili    S&S – Sansei Technologies
# 989          Wonder Woman Flight of Courage  Rocky Mountain Construction
#
#                            Location Opened  Year_Introduced  latitude  \
# ...

# %%
df_new["Year_Introduced"].value_counts().head(10).plot(kind="bar")
# Out:
# <Axes: xlabel='Year_Introduced'>

# %%
sns.pairplot(       )
